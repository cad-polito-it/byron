# %% [markdown]
# This notebook is part of [**Byron v0.8**](https://pypi.org/project/byron/)
# Copyright 2023-25 Giovanni Squillero and Alberto Tonda
# SPDX-License-Identifier: [Apache-2.0](https://www.apache.org/licenses/LICENSE-2.0)

# %%
import byron
# Out:
# /var/folders/31/dkl97hks2c14b663vl55pt440000gn/T/ipykernel_4441/1429530752.py:1: ByronPerformanceWarning:
#   Paranoia checks are enabled in this notebook: performances can be significantly impaired
#   [see https://cad-polito-it.github.io/byron/paranoia for details]
#   import byron

# %% [markdown]
# # Assembly Tutorial
#
# Oversimplified assembler vaguely based on x86 assembly

# %% [markdown]
# ## Framework
#
# Known as *Instruction Library* in MicroGP2 and *constraints* in MicroGP3

# %% [markdown]
# ### Operands: Registers and Immediate

# %%
reg8 = byron.f.choice_parameter(['ah', 'bh', 'ch', 'dh', 'al', 'bl', 'cl', 'dl'])
reg16 = byron.f.choice_parameter(['ax', 'bx', 'cx', 'dx'])
int8 = byron.f.integer_parameter(0, 2**8)
int16 = byron.f.integer_parameter(0, 2**16)

# %% [markdown]
# ### Operands: Registers and Immediate
#
# See https://docs.python.org/3/library/string.html#formatspec for the format specification

# %%
opcodes2 = byron.f.choice_parameter(['mov', 'add', 'sub', 'or', 'and'])
opcodes1 = byron.f.choice_parameter(['not', 'neg', 'inc', 'dec'])
opcodes0 = byron.f.choice_parameter(['nop', 'hlt'])

inst8rr = byron.f.macro("{op} {r1}, {r2}", op=opcodes2, r1=reg8, r2=reg8)
inst8ri = byron.f.macro("{op} {r}, {i:#x}", op=opcodes2, r=reg8, i=int8)
inst8r = byron.f.macro("{op} {r}", op=opcodes1, r=reg8)

inst16rr = byron.f.macro("{op} {r1}, {r2}", op=opcodes2, r1=reg16, r2=reg16)
inst16ri = byron.f.macro("{op} {r}, {i:#x}", op=opcodes2, r=reg16, i=int16)
inst16r = byron.f.macro("{op} {r}", op=opcodes1, r=reg16)

# %% [markdown]
# ### A simple fragment of code

# %%
prog = byron.f.bunch([inst16rr, inst16ri, inst16r, inst8rr, inst8ri, inst8r], 5)
byron.f.as_text(prog)
# Out:
# ; 🖋 n1 ➜ Frame❬MacroArray#1❭
# and ax, ax  ; 🖋 n1.n2 ➜ Macro❬User#4❭
# not ah  ; 🖋 n1.n3 ➜ Macro❬User#3❭
# dec ax  ; 🖋 n1.n4 ➜ Macro❬User#6❭
# and ax, 0x6ff1  ; 🖋 n1.n5 ➜ Macro❬User#5❭
# sub dx, 0x65ce  ; 🖋 n1.n6 ➜ Macro❬User#5❭

# %% [markdown]
# ### Add conditional branches (local references)

# %%
tests = byron.f.choice_parameter(['jz', 'jnz', 'jc', 'jnc', 'jo', 'jno', 'js', 'jns'])
branch = byron.f.macro("{test} {label}", test=tests, label=byron.f.local_reference())
prog = byron.f.bunch([inst16rr, inst16ri, inst16r, inst8rr, inst8ri, inst8r, branch], 7)

byron.f.as_lgp(prog, seed=1)

# %% [markdown]
# ### Let's add subroutines

# %%
sub_entry = byron.f.macro("\nproc {_node} near", _label='')
sub_exit = byron.f.macro("ret")
sub_body = byron.f.bunch([inst16rr, inst16ri, inst16r, inst8rr, inst8ri, inst8r], 3)
sub = byron.f.sequence([sub_entry, sub_body, sub_exit])

call = byron.f.macro("call {proc}", proc=byron.f.global_reference(sub, first_macro=True, creative_zeal=1))

# %% [markdown]
# Create a full program with header, initialization, and main body. Just for testing purpose, let "calls" be more frequent than the other instructions (62.5% of macros in `main_body` will be `call`).

# %%
main_prologue = """section .text

global _start
_start:
"""

test_main_body = byron.f.bunch(
    [inst16rr, inst16ri, inst16r, inst8rr, inst8ri, inst8r, branch, call], size=10, weights=[1, 1, 1, 1, 1, 1, 1, 10]
)
init = byron.f.macro("mov ax, {v:#x}\nmov bx, {v:#x}\nmov cx, {v:#x}\nmov dx, {v:#x}", v=int16)

full_prog = byron.f.sequence([main_prologue, init, test_main_body])

# %%
byron.f.as_text(full_prog, seed=2)
# Out:
# ; 🖋 n23 ➜ Frame❬FrameSequence#2❭
# section .text
#
# global _start
# _start:
#   ; 🖋 n23.n24 ➜ Macro❬Text#3❭
# mov ax, 0xc97d
# mov bx, 0xc97d
# mov cx, 0xc97d
# mov dx, 0xc97d  ; 🖋 n23.n25 ➜ Macro❬User#9❭
# ; 🖋 n23.n26 ➜ Frame❬MacroArray#4❭
# neg dx  ; 🖋 n23.n26.n27 ➜ Macro❬User#6❭
# neg ax  ; 🖋 n23.n26.n28 ➜ Macro❬User#6❭
# call n38  ; 🖋 n23.n26.n29 ➜ Macro❬User#8❭
# inc cl  ; 🖋 n23.n26.n30 ➜ Macro❬User#3❭
# n31:
# call n38  ; 🖋 n23.n26.n31 ➜ Macro❬User#8❭
# call n45  ; 🖋 n23.n26.n32 ➜ Macro❬User#8❭
# jz n31  ; 🖋 n23.n26.n33 ➜ Macro❬User#7❭
# or dx, 0xb535  ; 🖋 n23.n26.n34 ➜ Macro❬User#5❭
# neg dl  ; 🖋 n23.n26.n35 ➜ Macro❬User#3❭
# call n45  ; 🖋 n23.n26.n36 ➜ Macro❬User#8❭
# ; 🖋 n37 ➜ Frame❬FrameSequence#1❭
#
# proc n38 near  ; 🖋 n37.n38 ➜ Macro❬Text#1❭
# ; 🖋 n37.n39 ➜ Frame❬MacroArray#3❭
# or bh, bh  ; 🖋 n37.n39.n40 ➜ Macro❬User#1❭
# inc bx  ; 🖋 n37.n39.n41 ➜ Macro❬User#6❭
# add bh, cl  ; 🖋 n37.n39.n42 ➜ Macro❬User#1❭
# ret  ; 🖋 n37.n43 ➜ Macro❬Text#2❭
# ; 🖋 n44 ➜ Frame❬FrameSequence#1❭
#
# proc n45 near  ; 🖋 n44.n45 ➜ Macro❬Text#1❭
# ; 🖋 n44.n46 ➜ Frame❬MacroArray#3❭
# neg cl  ; 🖋 n44.n46.n47 ➜ Macro❬User#3❭
# and dh, 0xe4  ; 🖋 n44.n46.n48 ➜ Macro❬User#2❭
# not bx  ; 🖋 n44.n46.n49 ➜ Macro❬User#6❭
# ret  ; 🖋 n44.n50 ➜ Macro❬Text#2❭

# %%
byron.f.as_forest(full_prog, seed=2)
byron.f.as_lgp(full_prog, seed=2)

# %% [markdown]
# ### Final version

# %%
reg8 = byron.f.choice_parameter(['ah', 'bh', 'ch', 'dh', 'al', 'bl', 'cl', 'dl'])
reg16 = byron.f.choice_parameter(['ax', 'bx', 'cx', 'dx'])
int8 = byron.f.integer_parameter(0, 2**8)
int16 = byron.f.integer_parameter(0, 2**16)

opcodes2 = byron.f.choice_parameter(['mov', 'add', 'sub', 'or', 'and'])
opcodes1 = byron.f.choice_parameter(['not', 'neg', 'inc', 'dec'])
opcodes0 = byron.f.choice_parameter(['nop', 'hlt'])

inst8rr = byron.f.macro("{op} {r1}, {r2}", op=opcodes2, r1=reg8, r2=reg8)
inst8ri = byron.f.macro("{op} {r}, {i:#x}", op=opcodes2, r=reg8, i=int8)
inst8r = byron.f.macro("{op} {r}", op=opcodes1, r=reg8)
inst16rr = byron.f.macro("{op} {r1}, {r2}", op=opcodes2, r1=reg16, r2=reg16)
inst16ri = byron.f.macro("{op} {r}, {i:#x}", op=opcodes2, r=reg16, i=int16)
inst16r = byron.f.macro("{op} {r}", op=opcodes1, r=reg16)

tests = byron.f.choice_parameter(['jz', 'jnz', 'jc', 'jnc', 'jo', 'jno', 'js', 'jns'])
branch = byron.f.macro("{test} {label}", test=tests, label=byron.f.local_reference())

main_prologue = "section .text\nglobal _start\n_start:"
init = byron.f.macro("mov ax, {v:#x}\nmov bx, {v:#x}\nmov cx, {v:#x}\nmov dx, {v:#x}", v=int16)

sub_entry = byron.f.macro("\nproc {_node} near", _label='')
sub_exit = byron.f.macro("ret")
sub_body = byron.f.bunch([inst16rr, inst16ri, inst16r, inst8rr, inst8ri, inst8r], (2, 10))
sub = byron.f.sequence([sub_entry, sub_body, sub_exit])

call = byron.f.macro("call {proc}", proc=byron.f.global_reference(sub, first_macro=True, creative_zeal=1))

main_body = byron.f.bunch([inst16rr, inst16ri, inst16r, inst8rr, inst8ri, inst8r, branch, call], size=(5, 20))
full_prog = byron.f.sequence([main_prologue, init, main_body])

# %% [markdown]
# ## Evolutionary Algorithm

# %% [markdown]
# ### Fitness Function

# %%
@byron.fitness_function
def fitness(genotype):
    # print(genotype)
    return 0.0
    # raise Exception("Not implemented")

# %% [markdown]
# ### Let's roll
#
# Default logging level is `DEBUG` in notebooks and `INFO` in scripts. It is possible to change it with `byron.logger.setLevel(logging.INFO)`.

# %%
evaluator = byron.evaluator.PythonEvaluator(fitness, strip_phenotypes=True)
population = byron.ea.vanilla_ea(full_prog, evaluator, max_generation=5_000, lambda_=20, mu=30)
# Out:
# INFO ▷ VanillaEA: 🍦 [b]VanillaEA started[/] ┈ ⌛ 0:00:00.00 [t] / 🕙️  0:00:00.00 [byron]
# DEBUG ▷ Individual: Fitness of 𝐢9/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢10/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢11/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢12/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢13/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢14/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢15/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢16/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢17/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢18/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢19/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢20/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢21/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢22/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢23/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢24/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢25/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢26/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢27/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢28/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢29/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢30/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢31/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢32/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢33/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢34/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢35/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢36/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢37/random_individual() is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢38/random_individual() is 0Ƒ
# INFO ▷ VanillaEA: 🍀 𝐢38 ⇨ fitness: 0Ƒ / ⚝ 0
# INFO ▷ VanillaEA: End of initialization ┈ ⌛ 0:00:00.30 [t] / 🏃 0:00:00.01
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢69/remove_macro_from_bunch(𝐢20) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢70/node_crossover_unfussy(𝐢27, 𝐢37) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢73/add_macro_to_bunch(𝐢35) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢74/node_crossover_unfussy(𝐢22, 𝐢37) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢75/add_macro_to_bunch(𝐢19) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢77/leaf_crossover_unfussy(𝐢16, 𝐢23) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢78/remove_macro_from_bunch(𝐢15) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢80/remove_macro_from_bunch(𝐢21) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢81/node_crossover_choosy(𝐢21, 𝐢14) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢82/remove_macro_from_bunch(𝐢30) is 0Ƒ
# INFO ▷ VanillaEA: End of generation 1 (𝐻: 6.4370) ┈ ⌛ 0:00:00.43 [t] / 🏃 0:00:00.01
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢94/leaf_crossover_unfussy(𝐢37, 𝐢19) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢98/remove_macro_from_bunch(𝐢73) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢99/remove_macro_from_bunch(𝐢81) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢101/single_parameter_mutation(𝐢31) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢103/single_parameter_mutation(𝐢19) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢104/single_parameter_mutation(𝐢22) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢108/add_macro_to_bunch(𝐢21) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢109/leaf_crossover_unfussy(𝐢28, 𝐢75) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢110/add_macro_to_bunch(𝐢29) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢120/node_crossover_unfussy(𝐢36, 𝐢103) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢124/leaf_crossover_unfussy(𝐢34, 𝐢80) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢126/node_crossover_choosy(𝐢30, 𝐢104) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢127/single_parameter_mutation(𝐢75) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢128/single_parameter_mutation(𝐢70) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢129/single_parameter_mutation(𝐢78) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢134/node_crossover_unfussy(𝐢80, 𝐢78) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢135/add_macro_to_bunch(𝐢37) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢146/node_crossover_unfussy(𝐢69, 𝐢99) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢147/single_parameter_mutation(𝐢70) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢149/single_parameter_mutation(𝐢99) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢150/remove_macro_from_bunch(𝐢74) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢151/remove_macro_from_bunch(𝐢73) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢154/add_macro_to_bunch(𝐢78) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢155/node_crossover_unfussy(𝐢101, 𝐢103) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢157/single_parameter_mutation(𝐢82) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158/remove_macro_from_bunch(𝐢134) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢159/remove_macro_from_bunch(𝐢70) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢160/remove_macro_from_bunch(𝐢38) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢161/remove_macro_from_bunch(𝐢36) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢174/remove_macro_from_bunch(𝐢108) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢175/remove_macro_from_bunch(𝐢126) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢176/leaf_crossover_unfussy(𝐢126, 𝐢149) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢178/remove_macro_from_bunch(𝐢104) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢180/remove_macro_from_bunch(𝐢128) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢181/leaf_crossover_unfussy(𝐢104, 𝐢128) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢182/add_macro_to_bunch(𝐢104) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢183/single_parameter_mutation(𝐢103) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢184/single_parameter_mutation(𝐢161) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢185/single_parameter_mutation(𝐢127) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢186/single_parameter_mutation(𝐢127) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢187/add_macro_to_bunch(𝐢158) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢188/node_crossover_unfussy(𝐢159, 𝐢135) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢190/single_parameter_mutation(𝐢159) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢191/single_parameter_mutation(𝐢110) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢207/leaf_crossover_unfussy(𝐢135, 𝐢147) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢208/remove_macro_from_bunch(𝐢184) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢209/single_parameter_mutation(𝐢129) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢210/add_macro_to_bunch(𝐢129) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢212/node_crossover_unfussy(𝐢154, 𝐢180) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢213/single_parameter_mutation(𝐢187) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢215/remove_macro_from_bunch(𝐢151) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢216/leaf_crossover_unfussy(𝐢178, 𝐢187) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢217/node_crossover_unfussy(𝐢187, 𝐢178) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢219/remove_macro_from_bunch(𝐢158) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢220/add_macro_to_bunch(𝐢182) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢221/node_crossover_unfussy(𝐢181, 𝐢188) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢222/leaf_crossover_unfussy(𝐢187, 𝐢191) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢223/leaf_crossover_unfussy(𝐢180, 𝐢146) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢238/node_crossover_choosy(𝐢185, 𝐢216) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢240/remove_macro_from_bunch(𝐢210) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢242/add_macro_to_bunch(𝐢183) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢246/leaf_crossover_unfussy(𝐢186, 𝐢188) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢247/single_parameter_mutation(𝐢178) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢249/node_crossover_choosy(𝐢217, 𝐢222) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢251/remove_macro_from_bunch(𝐢188) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢252/add_macro_to_bunch(𝐢209) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢253/add_macro_to_bunch(𝐢209) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢255/leaf_crossover_unfussy(𝐢210, 𝐢222) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢267/remove_macro_from_bunch(𝐢216) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢268/single_parameter_mutation(𝐢207) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢269/node_crossover_unfussy(𝐢221, 𝐢246) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢270/node_crossover_choosy(𝐢223, 𝐢251) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢271/node_crossover_unfussy(𝐢213, 𝐢222) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢272/add_macro_to_bunch(𝐢223) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢273/node_crossover_unfussy(𝐢212, 𝐢221) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢274/leaf_crossover_unfussy(𝐢238, 𝐢223) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢275/single_parameter_mutation(𝐢217) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢276/leaf_crossover_unfussy(𝐢247, 𝐢255) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢278/leaf_crossover_unfussy(𝐢215, 𝐢213) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢279/leaf_crossover_unfussy(𝐢215, 𝐢220) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢280/leaf_crossover_unfussy(𝐢240, 𝐢188) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢281/add_macro_to_bunch(𝐢190) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢282/add_macro_to_bunch(𝐢223) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢298/add_macro_to_bunch(𝐢242) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢299/node_crossover_unfussy(𝐢255, 𝐢247) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢304/leaf_crossover_unfussy(𝐢223, 𝐢246) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢305/single_parameter_mutation(𝐢279) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢306/add_macro_to_bunch(𝐢221) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢307/add_macro_to_bunch(𝐢281) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢308/remove_macro_from_bunch(𝐢255) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢318/add_macro_to_bunch(𝐢268) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢319/node_crossover_unfussy(𝐢269, 𝐢247) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢320/remove_macro_from_bunch(𝐢281) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢323/node_crossover_unfussy(𝐢280, 𝐢251) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢326/single_parameter_mutation(𝐢278) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢328/single_parameter_mutation(𝐢281) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢330/node_crossover_unfussy(𝐢306, 𝐢271) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢332/add_macro_to_bunch(𝐢271) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢334/leaf_crossover_unfussy(𝐢269, 𝐢280) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢344/add_macro_to_bunch(𝐢275) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢345/add_macro_to_bunch(𝐢274) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢347/add_macro_to_bunch(𝐢318) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢348/single_parameter_mutation(𝐢319) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢349/add_macro_to_bunch(𝐢323) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢350/single_parameter_mutation(𝐢323) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢351/node_crossover_unfussy(𝐢330, 𝐢270) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢352/leaf_crossover_unfussy(𝐢334, 𝐢308) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢353/node_crossover_choosy(𝐢280, 𝐢273) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢354/node_crossover_unfussy(𝐢270, 𝐢308) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢355/single_parameter_mutation(𝐢326) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢356/remove_macro_from_bunch(𝐢269) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢357/single_parameter_mutation(𝐢304) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢371/add_macro_to_bunch(𝐢306) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢372/leaf_crossover_unfussy(𝐢347, 𝐢326) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢373/leaf_crossover_unfussy(𝐢349, 𝐢355) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢374/remove_macro_from_bunch(𝐢304) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢375/remove_macro_from_bunch(𝐢345) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢377/leaf_crossover_unfussy(𝐢326, 𝐢350) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢379/remove_macro_from_bunch(𝐢304) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢381/remove_macro_from_bunch(𝐢298) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢382/node_crossover_choosy(𝐢354, 𝐢332) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢383/single_parameter_mutation(𝐢344) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢384/remove_macro_from_bunch(𝐢282) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢385/add_macro_to_bunch(𝐢356) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢387/node_crossover_unfussy(𝐢351, 𝐢305) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢388/leaf_crossover_unfussy(𝐢326, 𝐢345) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢389/add_macro_to_bunch(𝐢357) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢407/remove_macro_from_bunch(𝐢354) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢408/add_macro_to_bunch(𝐢383) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢409/add_macro_to_bunch(𝐢354) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢411/remove_macro_from_bunch(𝐢389) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢412/remove_macro_from_bunch(𝐢347) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢413/add_macro_to_bunch(𝐢348) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢415/add_macro_to_bunch(𝐢350) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢418/node_crossover_unfussy(𝐢385, 𝐢347) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢429/add_macro_to_bunch(𝐢352) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢430/node_crossover_unfussy(𝐢373, 𝐢352) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢431/remove_macro_from_bunch(𝐢408) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢433/leaf_crossover_unfussy(𝐢411, 𝐢418) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢436/node_crossover_unfussy(𝐢409, 𝐢384) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢437/leaf_crossover_unfussy(𝐢382, 𝐢354) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢439/leaf_crossover_unfussy(𝐢375, 𝐢381) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢441/add_macro_to_bunch(𝐢408) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢442/add_macro_to_bunch(𝐢354) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢452/single_parameter_mutation(𝐢379) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢457/node_crossover_unfussy(𝐢441, 𝐢374) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢462/node_crossover_unfussy(𝐢387, 𝐢431) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢463/single_parameter_mutation(𝐢407) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢464/node_crossover_unfussy(𝐢436, 𝐢407) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢466/single_parameter_mutation(𝐢409) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢469/add_macro_to_bunch(𝐢377) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢477/remove_macro_from_bunch(𝐢385) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢480/remove_macro_from_bunch(𝐢441) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢481/node_crossover_unfussy(𝐢384, 𝐢436) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢482/node_crossover_unfussy(𝐢413, 𝐢418) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢486/single_parameter_mutation(𝐢388) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢489/remove_macro_from_bunch(𝐢409) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢490/node_crossover_choosy(𝐢418, 𝐢457) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢491/leaf_crossover_unfussy(𝐢462, 𝐢407) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢492/node_crossover_choosy(𝐢411, 𝐢436) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢493/remove_macro_from_bunch(𝐢418) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢504/add_macro_to_bunch(𝐢469) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢507/add_macro_to_bunch(𝐢491) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢508/add_macro_to_bunch(𝐢469) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢509/single_parameter_mutation(𝐢481) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢510/single_parameter_mutation(𝐢441) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢511/single_parameter_mutation(𝐢464) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢512/single_parameter_mutation(𝐢439) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢513/single_parameter_mutation(𝐢433) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢515/add_macro_to_bunch(𝐢482) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢516/add_macro_to_bunch(𝐢463) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢517/remove_macro_from_bunch(𝐢439) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢518/remove_macro_from_bunch(𝐢493) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢531/leaf_crossover_unfussy(𝐢508, 𝐢517) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢532/node_crossover_choosy(𝐢463, 𝐢492) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢533/add_macro_to_bunch(𝐢477) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢535/add_macro_to_bunch(𝐢515) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢536/add_macro_to_bunch(𝐢515) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢537/leaf_crossover_unfussy(𝐢463, 𝐢491) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢538/add_macro_to_bunch(𝐢490) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢540/remove_macro_from_bunch(𝐢477) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢541/remove_macro_from_bunch(𝐢490) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢543/single_parameter_mutation(𝐢489) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢544/node_crossover_unfussy(𝐢462, 𝐢491) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢545/leaf_crossover_unfussy(𝐢507, 𝐢490) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢546/node_crossover_choosy(𝐢504, 𝐢462) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢547/remove_macro_from_bunch(𝐢518) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢563/single_parameter_mutation(𝐢490) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢564/leaf_crossover_unfussy(𝐢510, 𝐢516) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢566/node_crossover_choosy(𝐢516, 𝐢531) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢567/node_crossover_choosy(𝐢536, 𝐢543) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢568/remove_macro_from_bunch(𝐢540) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢569/add_macro_to_bunch(𝐢509) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢571/single_parameter_mutation(𝐢510) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢574/leaf_crossover_unfussy(𝐢544, 𝐢510) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢576/node_crossover_unfussy(𝐢504, 𝐢535) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢577/remove_macro_from_bunch(𝐢512) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢588/add_macro_to_bunch(𝐢533) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢590/node_crossover_choosy(𝐢543, 𝐢569) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢591/leaf_crossover_unfussy(𝐢517, 𝐢546) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢592/add_macro_to_bunch(𝐢540) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢593/remove_macro_from_bunch(𝐢513) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢594/node_crossover_choosy(𝐢545, 𝐢571) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢595/add_macro_to_bunch(𝐢518) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢596/remove_macro_from_bunch(𝐢538) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢597/add_macro_to_bunch(𝐢577) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢601/single_parameter_mutation(𝐢532) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢613/leaf_crossover_unfussy(𝐢574, 𝐢546) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢614/node_crossover_unfussy(𝐢541, 𝐢566) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢616/remove_macro_from_bunch(𝐢563) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢617/add_macro_to_bunch(𝐢546) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢619/remove_macro_from_bunch(𝐢577) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢621/remove_macro_from_bunch(𝐢545) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢622/node_crossover_choosy(𝐢594, 𝐢577) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢625/add_macro_to_bunch(𝐢537) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢626/single_parameter_mutation(𝐢540) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢627/single_parameter_mutation(𝐢566) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢628/add_macro_to_bunch(𝐢576) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢640/add_macro_to_bunch(𝐢621) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢641/remove_macro_from_bunch(𝐢627) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢642/leaf_crossover_unfussy(𝐢564, 𝐢627) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢644/add_macro_to_bunch(𝐢597) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢645/leaf_crossover_unfussy(𝐢566, 𝐢593) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢647/remove_macro_from_bunch(𝐢622) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢648/remove_macro_from_bunch(𝐢596) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢649/leaf_crossover_unfussy(𝐢594, 𝐢621) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢651/single_parameter_mutation(𝐢566) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢653/single_parameter_mutation(𝐢566) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢655/leaf_crossover_unfussy(𝐢567, 𝐢617) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢669/add_macro_to_bunch(𝐢649) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢672/single_parameter_mutation(𝐢592) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢673/node_crossover_unfussy(𝐢628, 𝐢601) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢674/node_crossover_choosy(𝐢617, 𝐢591) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢677/single_parameter_mutation(𝐢601) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢678/single_parameter_mutation(𝐢627) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢679/add_macro_to_bunch(𝐢628) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢681/node_crossover_choosy(𝐢595, 𝐢601) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢682/single_parameter_mutation(𝐢595) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢683/node_crossover_unfussy(𝐢651, 𝐢644) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢685/add_macro_to_bunch(𝐢614) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢697/remove_macro_from_bunch(𝐢642) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢698/remove_macro_from_bunch(𝐢641) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢700/remove_macro_from_bunch(𝐢647) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢702/node_crossover_choosy(𝐢622, 𝐢642) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢706/single_parameter_mutation(𝐢648) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢707/node_crossover_choosy(𝐢647, 𝐢628) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢708/node_crossover_choosy(𝐢677, 𝐢673) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢709/remove_macro_from_bunch(𝐢627) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢710/remove_macro_from_bunch(𝐢677) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢712/leaf_crossover_unfussy(𝐢642, 𝐢621) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢724/node_crossover_unfussy(𝐢678, 𝐢710) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢726/node_crossover_choosy(𝐢683, 𝐢681) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢727/node_crossover_unfussy(𝐢698, 𝐢673) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢728/remove_macro_from_bunch(𝐢674) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢729/add_macro_to_bunch(𝐢648) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢730/node_crossover_unfussy(𝐢678, 𝐢644) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢732/add_macro_to_bunch(𝐢710) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢733/node_crossover_choosy(𝐢683, 𝐢642) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢735/remove_macro_from_bunch(𝐢673) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢737/node_crossover_choosy(𝐢700, 𝐢669) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢738/add_macro_to_bunch(𝐢706) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢750/node_crossover_unfussy(𝐢733, 𝐢673) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢752/add_macro_to_bunch(𝐢735) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢754/add_macro_to_bunch(𝐢738) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢758/node_crossover_unfussy(𝐢727, 𝐢738) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢759/single_parameter_mutation(𝐢681) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢760/single_parameter_mutation(𝐢702) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢761/node_crossover_unfussy(𝐢710, 𝐢683) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢764/node_crossover_unfussy(𝐢729, 𝐢730) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢766/add_macro_to_bunch(𝐢737) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢767/add_macro_to_bunch(𝐢683) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢778/remove_macro_from_bunch(𝐢738) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢779/leaf_crossover_unfussy(𝐢710, 𝐢738) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢781/remove_macro_from_bunch(𝐢700) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢783/node_crossover_unfussy(𝐢708, 𝐢754) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢785/remove_macro_from_bunch(𝐢730) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢786/add_macro_to_bunch(𝐢724) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢788/node_crossover_unfussy(𝐢738, 𝐢707) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢790/add_macro_to_bunch(𝐢737) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢791/node_crossover_choosy(𝐢698, 𝐢708) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢793/node_crossover_choosy(𝐢728, 𝐢708) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢794/node_crossover_unfussy(𝐢737, 𝐢752) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢795/leaf_crossover_unfussy(𝐢758, 𝐢728) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢796/add_macro_to_bunch(𝐢764) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢812/node_crossover_choosy(𝐢738, 𝐢760) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢815/add_macro_to_bunch(𝐢790) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢816/remove_macro_from_bunch(𝐢758) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢817/leaf_crossover_unfussy(𝐢729, 𝐢794) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢818/node_crossover_unfussy(𝐢733, 𝐢750) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢820/remove_macro_from_bunch(𝐢761) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢821/node_crossover_unfussy(𝐢788, 𝐢752) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢823/node_crossover_choosy(𝐢760, 𝐢781) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢824/remove_macro_from_bunch(𝐢759) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢826/single_parameter_mutation(𝐢738) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢827/add_macro_to_bunch(𝐢730) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢840/add_macro_to_bunch(𝐢823) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢841/remove_macro_from_bunch(𝐢817) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢842/node_crossover_unfussy(𝐢786, 𝐢778) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢843/node_crossover_unfussy(𝐢824, 𝐢759) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢845/single_parameter_mutation(𝐢783) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢847/node_crossover_choosy(𝐢790, 𝐢821) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢848/remove_macro_from_bunch(𝐢794) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢849/add_macro_to_bunch(𝐢812) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢851/add_macro_to_bunch(𝐢767) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢852/node_crossover_choosy(𝐢818, 𝐢785) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢853/leaf_crossover_unfussy(𝐢785, 𝐢826) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢854/add_macro_to_bunch(𝐢767) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢856/leaf_crossover_unfussy(𝐢791, 𝐢818) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢870/leaf_crossover_unfussy(𝐢818, 𝐢851) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢871/single_parameter_mutation(𝐢845) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢875/node_crossover_unfussy(𝐢847, 𝐢823) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢877/leaf_crossover_unfussy(𝐢821, 𝐢856) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢878/remove_macro_from_bunch(𝐢823) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢879/node_crossover_unfussy(𝐢791, 𝐢856) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢880/node_crossover_choosy(𝐢791, 𝐢851) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢881/remove_macro_from_bunch(𝐢820) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢882/node_crossover_choosy(𝐢826, 𝐢848) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢884/node_crossover_unfussy(𝐢790, 𝐢851) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢887/add_macro_to_bunch(𝐢812) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢900/single_parameter_mutation(𝐢827) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢901/remove_macro_from_bunch(𝐢845) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢903/add_macro_to_bunch(𝐢849) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢904/leaf_crossover_unfussy(𝐢851, 𝐢878) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢905/leaf_crossover_unfussy(𝐢841, 𝐢852) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢906/leaf_crossover_unfussy(𝐢852, 𝐢884) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢908/single_parameter_mutation(𝐢841) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢909/leaf_crossover_unfussy(𝐢882, 𝐢881) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢910/node_crossover_unfussy(𝐢853, 𝐢887) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢912/add_macro_to_bunch(𝐢841) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢913/single_parameter_mutation(𝐢827) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢914/add_macro_to_bunch(𝐢823) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢915/leaf_crossover_unfussy(𝐢871, 𝐢881) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢929/single_parameter_mutation(𝐢884) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢930/leaf_crossover_unfussy(𝐢906, 𝐢875) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢931/single_parameter_mutation(𝐢906) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢932/single_parameter_mutation(𝐢909) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢933/add_macro_to_bunch(𝐢852) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢934/node_crossover_unfussy(𝐢909, 𝐢904) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢935/single_parameter_mutation(𝐢913) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢936/node_crossover_unfussy(𝐢853, 𝐢887) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢937/add_macro_to_bunch(𝐢912) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢939/leaf_crossover_unfussy(𝐢854, 𝐢878) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢943/node_crossover_choosy(𝐢856, 𝐢875) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢944/remove_macro_from_bunch(𝐢903) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢957/single_parameter_mutation(𝐢934) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢959/single_parameter_mutation(𝐢930) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢960/node_crossover_unfussy(𝐢935, 𝐢882) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢963/single_parameter_mutation(𝐢887) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢964/remove_macro_from_bunch(𝐢930) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢965/add_macro_to_bunch(𝐢900) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢967/single_parameter_mutation(𝐢904) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢968/node_crossover_choosy(𝐢913, 𝐢937) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢969/remove_macro_from_bunch(𝐢930) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢970/node_crossover_choosy(𝐢900, 𝐢937) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢971/single_parameter_mutation(𝐢906) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢972/node_crossover_choosy(𝐢909, 𝐢936) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢974/node_crossover_choosy(𝐢909, 𝐢936) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢988/single_parameter_mutation(𝐢971) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢990/leaf_crossover_unfussy(𝐢935, 𝐢914) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢991/add_macro_to_bunch(𝐢913) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢992/node_crossover_choosy(𝐢943, 𝐢971) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢993/add_macro_to_bunch(𝐢963) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢996/node_crossover_unfussy(𝐢971, 𝐢914) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢997/remove_macro_from_bunch(𝐢968) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢999/node_crossover_unfussy(𝐢960, 𝐢932) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1000/add_macro_to_bunch(𝐢932) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1001/single_parameter_mutation(𝐢934) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1003/single_parameter_mutation(𝐢931) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1018/add_macro_to_bunch(𝐢1000) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1019/node_crossover_unfussy(𝐢967, 𝐢972) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1020/leaf_crossover_unfussy(𝐢937, 𝐢959) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1021/single_parameter_mutation(𝐢965) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1022/leaf_crossover_unfussy(𝐢959, 𝐢957) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1027/single_parameter_mutation(𝐢969) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1028/node_crossover_unfussy(𝐢974, 𝐢943) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1030/single_parameter_mutation(𝐢960) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1031/single_parameter_mutation(𝐢990) is 0Ƒ
# /Users/giovanni/Repos/byron/byron/ea/vanilla.py:140: ByronPerformanceWarning:
#   The failure rate of 'array_parameter_uniform_crossover_choosy' is 100% (0 successes out of 100 calls)
#   new_individuals += op(*parents)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1043/add_macro_to_bunch(𝐢972) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1044/single_parameter_mutation(𝐢1001) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1045/add_macro_to_bunch(𝐢967) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1046/node_crossover_choosy(𝐢1030, 𝐢969) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1047/node_crossover_unfussy(𝐢993, 𝐢970) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1048/leaf_crossover_unfussy(𝐢1018, 𝐢965) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1049/node_crossover_choosy(𝐢992, 𝐢1030) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1051/node_crossover_unfussy(𝐢996, 𝐢970) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1052/add_macro_to_bunch(𝐢1001) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1054/remove_macro_from_bunch(𝐢970) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1055/single_parameter_mutation(𝐢988) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1058/node_crossover_unfussy(𝐢972, 𝐢974) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1060/add_macro_to_bunch(𝐢969) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1075/remove_macro_from_bunch(𝐢1020) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1076/add_macro_to_bunch(𝐢1022) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1079/single_parameter_mutation(𝐢992) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1080/add_macro_to_bunch(𝐢1003) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1081/node_crossover_unfussy(𝐢1043, 𝐢1000) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1082/node_crossover_unfussy(𝐢1003, 𝐢1028) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1083/node_crossover_unfussy(𝐢1058, 𝐢1019) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1085/node_crossover_unfussy(𝐢1018, 𝐢1003) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1087/remove_macro_from_bunch(𝐢1052) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1088/remove_macro_from_bunch(𝐢1028) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1089/leaf_crossover_unfussy(𝐢1060, 𝐢1058) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1091/leaf_crossover_unfussy(𝐢1018, 𝐢1022) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1092/single_parameter_mutation(𝐢1001) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1093/single_parameter_mutation(𝐢993) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1108/add_macro_to_bunch(𝐢1043) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1109/remove_macro_from_bunch(𝐢1075) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1111/add_macro_to_bunch(𝐢1080) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1113/node_crossover_unfussy(𝐢1087, 𝐢1054) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1115/node_crossover_unfussy(𝐢1045, 𝐢1030) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1118/add_macro_to_bunch(𝐢1085) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1119/single_parameter_mutation(𝐢1051) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1123/single_parameter_mutation(𝐢1085) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1124/leaf_crossover_unfussy(𝐢1058, 𝐢1048) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1125/remove_macro_from_bunch(𝐢1075) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1137/add_macro_to_bunch(𝐢1115) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1138/node_crossover_unfussy(𝐢1113, 𝐢1052) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1140/remove_macro_from_bunch(𝐢1091) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1141/leaf_crossover_unfussy(𝐢1124, 𝐢1118) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1142/node_crossover_choosy(𝐢1118, 𝐢1082) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1143/leaf_crossover_unfussy(𝐢1089, 𝐢1093) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1144/remove_macro_from_bunch(𝐢1123) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1145/node_crossover_choosy(𝐢1089, 𝐢1052) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1146/single_parameter_mutation(𝐢1124) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1147/remove_macro_from_bunch(𝐢1123) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1148/remove_macro_from_bunch(𝐢1118) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1152/add_macro_to_bunch(𝐢1058) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1165/single_parameter_mutation(𝐢1118) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1166/single_parameter_mutation(𝐢1146) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1167/node_crossover_choosy(𝐢1137, 𝐢1115) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1168/node_crossover_choosy(𝐢1137, 𝐢1118) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1169/node_crossover_choosy(𝐢1137, 𝐢1118) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1171/remove_macro_from_bunch(𝐢1118) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1172/node_crossover_unfussy(𝐢1108, 𝐢1145) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1174/node_crossover_choosy(𝐢1124, 𝐢1109) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1175/leaf_crossover_unfussy(𝐢1137, 𝐢1091) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1177/add_macro_to_bunch(𝐢1144) is 0Ƒ
# INFO ▷ VanillaEA: End of generation 40 (𝐻: 6.7816) ┈ ⌛ 0:00:05.50 [t] / 🏃 0:00:00.01
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1189/add_macro_to_bunch(𝐢1119) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1190/add_macro_to_bunch(𝐢1137) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1192/remove_macro_from_bunch(𝐢1141) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1194/node_crossover_unfussy(𝐢1168, 𝐢1140) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1195/add_macro_to_bunch(𝐢1125) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1196/node_crossover_choosy(𝐢1165, 𝐢1115) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1197/leaf_crossover_unfussy(𝐢1165, 𝐢1124) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1199/single_parameter_mutation(𝐢1146) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1200/add_macro_to_bunch(𝐢1142) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1201/leaf_crossover_unfussy(𝐢1175, 𝐢1165) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1202/remove_macro_from_bunch(𝐢1177) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1205/remove_macro_from_bunch(𝐢1177) is 0Ƒ
# /Users/giovanni/Repos/byron/byron/ea/vanilla.py:140: ByronPerformanceWarning:
#   The failure rate of 'single_element_array_parameter_mutation' is 100% (0 successes out of 100 calls)
#   new_individuals += op(*parents)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1219/leaf_crossover_unfussy(𝐢1168, 𝐢1194) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1220/single_parameter_mutation(𝐢1144) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1221/add_macro_to_bunch(𝐢1190) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1222/node_crossover_choosy(𝐢1175, 𝐢1189) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1223/add_macro_to_bunch(𝐢1147) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1224/node_crossover_choosy(𝐢1200, 𝐢1189) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1225/add_macro_to_bunch(𝐢1171) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1226/add_macro_to_bunch(𝐢1142) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1227/add_macro_to_bunch(𝐢1152) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1232/remove_macro_from_bunch(𝐢1168) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1233/single_parameter_mutation(𝐢1201) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1245/single_parameter_mutation(𝐢1197) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1246/add_macro_to_bunch(𝐢1169) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1247/add_macro_to_bunch(𝐢1200) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1248/remove_macro_from_bunch(𝐢1197) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1250/add_macro_to_bunch(𝐢1199) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1253/node_crossover_unfussy(𝐢1220, 𝐢1201) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1254/add_macro_to_bunch(𝐢1233) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1255/add_macro_to_bunch(𝐢1202) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1256/node_crossover_choosy(𝐢1223, 𝐢1202) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1258/node_crossover_choosy(𝐢1199, 𝐢1202) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1260/leaf_crossover_unfussy(𝐢1222, 𝐢1225) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1261/leaf_crossover_unfussy(𝐢1190, 𝐢1224) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1263/single_parameter_mutation(𝐢1175) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1277/node_crossover_choosy(𝐢1246, 𝐢1224) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1278/node_crossover_unfussy(𝐢1246, 𝐢1233) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1279/remove_macro_from_bunch(𝐢1222) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1281/single_parameter_mutation(𝐢1232) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1282/node_crossover_unfussy(𝐢1250, 𝐢1227) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1283/remove_macro_from_bunch(𝐢1248) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1284/remove_macro_from_bunch(𝐢1223) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1287/leaf_crossover_unfussy(𝐢1233, 𝐢1202) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1289/node_crossover_unfussy(𝐢1250, 𝐢1232) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1290/add_macro_to_bunch(𝐢1224) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1291/remove_macro_from_bunch(𝐢1246) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1305/node_crossover_unfussy(𝐢1279, 𝐢1248) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1307/remove_macro_from_bunch(𝐢1232) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1308/node_crossover_unfussy(𝐢1260, 𝐢1290) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1310/single_parameter_mutation(𝐢1245) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1313/node_crossover_choosy(𝐢1247, 𝐢1289) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1316/node_crossover_choosy(𝐢1277, 𝐢1245) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1317/add_macro_to_bunch(𝐢1287) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1318/single_parameter_mutation(𝐢1224) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1320/remove_macro_from_bunch(𝐢1278) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1321/node_crossover_choosy(𝐢1225, 𝐢1248) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1322/add_macro_to_bunch(𝐢1246) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1334/single_parameter_mutation(𝐢1260) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1337/add_macro_to_bunch(𝐢1255) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1340/add_macro_to_bunch(𝐢1320) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1341/leaf_crossover_unfussy(𝐢1290, 𝐢1255) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1342/remove_macro_from_bunch(𝐢1291) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1344/remove_macro_from_bunch(𝐢1263) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1346/remove_macro_from_bunch(𝐢1284) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1348/node_crossover_choosy(𝐢1317, 𝐢1282) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1360/single_parameter_mutation(𝐢1337) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1361/single_parameter_mutation(𝐢1310) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1363/single_parameter_mutation(𝐢1313) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1365/add_macro_to_bunch(𝐢1281) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1370/single_parameter_mutation(𝐢1344) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1371/node_crossover_choosy(𝐢1284, 𝐢1277) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1373/node_crossover_unfussy(𝐢1344, 𝐢1340) is 0Ƒ
# DEBUG ▷ generic_node_crossover: Failed (invalid structure, tree)
# DEBUG ▷ Individual: Fitness of 𝐢1381/remove_macro_from_bunch(𝐢1361) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢1382/add_macro_to_bunch(𝐢1365) is 0Ƒ
# ...
# DEBUG ▷ Individual: Fitness of 𝐢158309/single_parameter_mutation(𝐢158246) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158310/leaf_crossover_unfussy(𝐢158274, 𝐢158241) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158312/leaf_crossover_unfussy(𝐢158273, 𝐢158251) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158315/add_macro_to_bunch(𝐢158274) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158316/add_macro_to_bunch(𝐢158285) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158317/node_crossover_choosy(𝐢158245, 𝐢158255) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158318/remove_macro_from_bunch(𝐢158292) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158319/single_parameter_mutation(𝐢158247) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158320/single_parameter_mutation(𝐢158247) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158321/single_parameter_mutation(𝐢158285) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158324/leaf_crossover_unfussy(𝐢158247, 𝐢158249) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158325/leaf_crossover_unfussy(𝐢158292, 𝐢158240) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158340/single_parameter_mutation(𝐢158289) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158342/add_macro_to_bunch(𝐢158292) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158345/add_macro_to_bunch(𝐢158279) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158346/single_parameter_mutation(𝐢158325) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158347/leaf_crossover_unfussy(𝐢158281, 𝐢158316) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158348/node_crossover_unfussy(𝐢158319, 𝐢158255) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158350/add_macro_to_bunch(𝐢158318) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158351/leaf_crossover_unfussy(𝐢158279, 𝐢158287) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158352/node_crossover_unfussy(𝐢158318, 𝐢158286) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158353/leaf_crossover_unfussy(𝐢158292, 𝐢158281) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158354/node_crossover_unfussy(𝐢158282, 𝐢158274) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158356/remove_macro_from_bunch(𝐢158283) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158357/node_crossover_choosy(𝐢158292, 𝐢158288) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158358/leaf_crossover_unfussy(𝐢158321, 𝐢158285) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158373/add_macro_to_bunch(𝐢158350) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158375/node_crossover_unfussy(𝐢158310, 𝐢158351) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158379/node_crossover_choosy(𝐢158350, 𝐢158353) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158380/node_crossover_choosy(𝐢158288, 𝐢158340) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158381/single_parameter_mutation(𝐢158310) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158382/single_parameter_mutation(𝐢158324) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158383/leaf_crossover_unfussy(𝐢158312, 𝐢158357) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158384/remove_macro_from_bunch(𝐢158316) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158385/remove_macro_from_bunch(𝐢158324) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158386/add_macro_to_bunch(𝐢158310) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158388/remove_macro_from_bunch(𝐢158358) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158389/node_crossover_choosy(𝐢158324, 𝐢158354) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158390/node_crossover_unfussy(𝐢158309, 𝐢158351) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158391/remove_macro_from_bunch(𝐢158358) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158406/remove_macro_from_bunch(𝐢158391) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158407/node_crossover_choosy(𝐢158384, 𝐢158347) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158408/node_crossover_unfussy(𝐢158380, 𝐢158350) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158409/single_parameter_mutation(𝐢158388) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158410/leaf_crossover_unfussy(𝐢158351, 𝐢158345) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158411/node_crossover_choosy(𝐢158352, 𝐢158373) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158413/node_crossover_choosy(𝐢158390, 𝐢158373) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158415/remove_macro_from_bunch(𝐢158358) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158417/node_crossover_choosy(𝐢158342, 𝐢158373) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158419/single_parameter_mutation(𝐢158348) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158420/single_parameter_mutation(𝐢158381) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158421/remove_macro_from_bunch(𝐢158356) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158422/leaf_crossover_unfussy(𝐢158381, 𝐢158353) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158423/remove_macro_from_bunch(𝐢158388) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158424/remove_macro_from_bunch(𝐢158381) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158441/single_parameter_mutation(𝐢158382) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158443/single_parameter_mutation(𝐢158391) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158444/single_parameter_mutation(𝐢158406) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158445/remove_macro_from_bunch(𝐢158413) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158446/add_macro_to_bunch(𝐢158410) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158450/node_crossover_unfussy(𝐢158415, 𝐢158409) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158452/single_parameter_mutation(𝐢158379) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158453/add_macro_to_bunch(𝐢158421) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158455/node_crossover_choosy(𝐢158413, 𝐢158419) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158456/add_macro_to_bunch(𝐢158417) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158457/add_macro_to_bunch(𝐢158413) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158459/add_macro_to_bunch(𝐢158389) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158472/leaf_crossover_unfussy(𝐢158423, 𝐢158391) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158473/remove_macro_from_bunch(𝐢158413) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158474/remove_macro_from_bunch(𝐢158450) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158475/add_macro_to_bunch(𝐢158389) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158479/single_parameter_mutation(𝐢158452) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158480/remove_macro_from_bunch(𝐢158413) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158481/leaf_crossover_unfussy(𝐢158422, 𝐢158453) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158482/remove_macro_from_bunch(𝐢158421) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158483/node_crossover_unfussy(𝐢158450, 𝐢158410) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158484/node_crossover_unfussy(𝐢158413, 𝐢158419) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158485/node_crossover_choosy(𝐢158446, 𝐢158455) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158486/leaf_crossover_unfussy(𝐢158459, 𝐢158450) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158487/single_parameter_mutation(𝐢158441) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158488/node_crossover_choosy(𝐢158389, 𝐢158441) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158489/add_macro_to_bunch(𝐢158446) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158490/remove_macro_from_bunch(𝐢158391) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158508/node_crossover_choosy(𝐢158423, 𝐢158456) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158509/single_parameter_mutation(𝐢158481) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158511/single_parameter_mutation(𝐢158456) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158512/single_parameter_mutation(𝐢158456) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158513/remove_macro_from_bunch(𝐢158473) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158514/single_parameter_mutation(𝐢158484) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158516/node_crossover_choosy(𝐢158423, 𝐢158452) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158517/leaf_crossover_unfussy(𝐢158486, 𝐢158450) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158518/single_parameter_mutation(𝐢158457) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158519/remove_macro_from_bunch(𝐢158490) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158521/node_crossover_unfussy(𝐢158455, 𝐢158473) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158522/remove_macro_from_bunch(𝐢158485) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158523/node_crossover_choosy(𝐢158474, 𝐢158484) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158524/node_crossover_choosy(𝐢158453, 𝐢158485) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158525/node_crossover_choosy(𝐢158445, 𝐢158446) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158526/leaf_crossover_unfussy(𝐢158488, 𝐢158481) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158527/remove_macro_from_bunch(𝐢158489) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158546/node_crossover_choosy(𝐢158525, 𝐢158475) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158551/add_macro_to_bunch(𝐢158479) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158552/single_parameter_mutation(𝐢158479) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158553/node_crossover_unfussy(𝐢158508, 𝐢158519) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158554/remove_macro_from_bunch(𝐢158489) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158555/leaf_crossover_unfussy(𝐢158523, 𝐢158481) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158556/node_crossover_unfussy(𝐢158475, 𝐢158517) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158557/remove_macro_from_bunch(𝐢158526) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158559/node_crossover_unfussy(𝐢158487, 𝐢158514) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158560/remove_macro_from_bunch(𝐢158488) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158561/leaf_crossover_unfussy(𝐢158526, 𝐢158489) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158562/node_crossover_unfussy(𝐢158516, 𝐢158508) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158578/node_crossover_choosy(𝐢158490, 𝐢158523) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158579/remove_macro_from_bunch(𝐢158521) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158580/remove_macro_from_bunch(𝐢158527) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158585/remove_macro_from_bunch(𝐢158555) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158586/single_parameter_mutation(𝐢158525) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158587/node_crossover_unfussy(𝐢158527, 𝐢158512) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158590/add_macro_to_bunch(𝐢158560) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158591/leaf_crossover_unfussy(𝐢158521, 𝐢158508) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158592/leaf_crossover_unfussy(𝐢158511, 𝐢158555) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158605/node_crossover_unfussy(𝐢158560, 𝐢158580) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158606/single_parameter_mutation(𝐢158521) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158607/leaf_crossover_unfussy(𝐢158587, 𝐢158579) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158608/node_crossover_unfussy(𝐢158556, 𝐢158559) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158609/node_crossover_unfussy(𝐢158561, 𝐢158557) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158611/single_parameter_mutation(𝐢158562) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158613/node_crossover_unfussy(𝐢158560, 𝐢158527) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158614/add_macro_to_bunch(𝐢158527) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158615/node_crossover_choosy(𝐢158560, 𝐢158518) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158618/remove_macro_from_bunch(𝐢158519) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158619/node_crossover_choosy(𝐢158592, 𝐢158519) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158620/remove_macro_from_bunch(𝐢158525) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158621/single_parameter_mutation(𝐢158518) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158635/add_macro_to_bunch(𝐢158586) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158636/leaf_crossover_unfussy(𝐢158620, 𝐢158587) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158637/add_macro_to_bunch(𝐢158587) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158641/leaf_crossover_unfussy(𝐢158559, 𝐢158557) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158642/node_crossover_choosy(𝐢158611, 𝐢158555) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158643/node_crossover_unfussy(𝐢158590, 𝐢158621) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158644/node_crossover_unfussy(𝐢158590, 𝐢158580) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158645/node_crossover_choosy(𝐢158587, 𝐢158579) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158646/node_crossover_choosy(𝐢158585, 𝐢158591) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158647/remove_macro_from_bunch(𝐢158615) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158649/node_crossover_choosy(𝐢158621, 𝐢158587) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158650/node_crossover_choosy(𝐢158621, 𝐢158556) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158651/node_crossover_choosy(𝐢158557, 𝐢158560) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158652/leaf_crossover_unfussy(𝐢158619, 𝐢158609) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158667/node_crossover_choosy(𝐢158614, 𝐢158635) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158668/node_crossover_choosy(𝐢158647, 𝐢158607) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158669/node_crossover_choosy(𝐢158614, 𝐢158611) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158671/add_macro_to_bunch(𝐢158651) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158672/node_crossover_choosy(𝐢158645, 𝐢158615) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158673/remove_macro_from_bunch(𝐢158591) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158674/add_macro_to_bunch(𝐢158614) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158676/node_crossover_choosy(𝐢158608, 𝐢158606) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158677/remove_macro_from_bunch(𝐢158642) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158678/node_crossover_unfussy(𝐢158641, 𝐢158605) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158679/remove_macro_from_bunch(𝐢158609) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158680/remove_macro_from_bunch(𝐢158611) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158681/node_crossover_choosy(𝐢158635, 𝐢158609) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158683/add_macro_to_bunch(𝐢158650) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158684/remove_macro_from_bunch(𝐢158642) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158685/leaf_crossover_unfussy(𝐢158642, 𝐢158607) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158702/node_crossover_choosy(𝐢158650, 𝐢158644) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158703/single_parameter_mutation(𝐢158637) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158704/leaf_crossover_unfussy(𝐢158641, 𝐢158678) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158706/add_macro_to_bunch(𝐢158678) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158707/node_crossover_choosy(𝐢158674, 𝐢158650) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158708/add_macro_to_bunch(𝐢158676) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158709/remove_macro_from_bunch(𝐢158635) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158710/leaf_crossover_unfussy(𝐢158667, 𝐢158684) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158712/node_crossover_unfussy(𝐢158650, 𝐢158681) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158713/node_crossover_unfussy(𝐢158681, 𝐢158635) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158715/add_macro_to_bunch(𝐢158649) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158717/add_macro_to_bunch(𝐢158685) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158718/node_crossover_choosy(𝐢158679, 𝐢158649) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158719/add_macro_to_bunch(𝐢158674) is 0Ƒ
# INFO ▷ VanillaEA: End of generation 4999 (𝐻: 6.5185) ┈ ⌛ 0:10:49.53 [t] / 🏃 0:00:00.00
# DEBUG ▷ Individual: Fitness of 𝐢158735/add_macro_to_bunch(𝐢158669) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158736/add_macro_to_bunch(𝐢158718) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158738/single_parameter_mutation(𝐢158710) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158739/node_crossover_unfussy(𝐢158676, 𝐢158703) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158740/single_parameter_mutation(𝐢158718) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158742/remove_macro_from_bunch(𝐢158679) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158744/add_macro_to_bunch(𝐢158706) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158745/node_crossover_unfussy(𝐢158708, 𝐢158681) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158746/leaf_crossover_unfussy(𝐢158672, 𝐢158669) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158747/remove_macro_from_bunch(𝐢158712) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158748/add_macro_to_bunch(𝐢158710) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158749/single_parameter_mutation(𝐢158683) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158750/node_crossover_choosy(𝐢158671, 𝐢158676) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158752/single_parameter_mutation(𝐢158715) is 0Ƒ
# DEBUG ▷ Individual: Fitness of 𝐢158754/remove_macro_from_bunch(𝐢158706) is 0Ƒ
# INFO ▷ VanillaEA: 🍦 [b]VanillaEA completed[/] ┈ ⌛ 0:10:49.65 [t] / 🕙️  0:10:43.37 [byron]
# INFO ▷ VanillaEA: 🏆 𝐢158754 ⇨ fitness: 0Ƒ / ⚝ 5000 / remove_macro_from_bunch(𝐢158706)

# %%
byron.logger.info("Hey")
# Out:
# INFO ▷ Hey
