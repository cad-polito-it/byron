# %% [markdown]
# This notebook is part of [**Byron v0.8**](https://pypi.org/project/byron/)
# Copyright 2023 Giovanni Squillero and Alberto Tonda
# SPDX-License-Identifier: [Apache-2.0](https://www.apache.org/licenses/LICENSE-2.0)

# %%
import byron
# Out:
# /var/folders/31/dkl97hks2c14b663vl55pt440000gn/T/ipykernel_14886/1429530752.py:1: ByronPerformanceWarning:
#   Paranoia checks are enabled in this notebook: performances can be significantly impaired
#   [see https://github.com/cad-polito-it/byron/blob/pre-alpha/docs/paranoia.md for details]
#   import byron

# %% [markdown]
# Everything for the definition of the constraints (the old "instruction library") is under the namespace `byron.framework` (lazy fingers can use `byron.f`)

# %% [markdown]
# # Frames

# %%
macro_foo = byron.f.macro('foo #{num:04x}', num=byron.f.integer_parameter(0, 2**16))
macro_bar = byron.f.macro('bar {num:+0.3e}', num=byron.f.float_parameter(-1, 1))
macro_baz = byron.f.macro('baz 0x{array}', array=byron.f.array_parameter("0123456789abcdef", 8))

# %% [markdown]
# ## Macro bunches
#
# Macro bunches are sequences of macros randomly selected from a bunch.

# %%
bunch = byron.f.bunch([macro_foo, macro_bar, macro_baz], size=(5, 10 + 1))
byron.f.as_text(bunch)
# Out:
# ; 🖋 n1 ➜ Frame❬MacroBunch#1❭
# bar -2.584e-01  ; 🖋 n1.n2 ➜ Macro❬User#2❭
# baz 0xead7381d  ; 🖋 n1.n3 ➜ Macro❬User#3❭
# baz 0xac5fec37  ; 🖋 n1.n4 ➜ Macro❬User#3❭
# foo #0b36  ; 🖋 n1.n5 ➜ Macro❬User#1❭
# baz 0x2abf5573  ; 🖋 n1.n6 ➜ Macro❬User#3❭
# baz 0x273a6db4  ; 🖋 n1.n7 ➜ Macro❬User#3❭
# baz 0xdc64a230  ; 🖋 n1.n8 ➜ Macro❬User#3❭
# foo #c973  ; 🖋 n1.n9 ➜ Macro❬User#1❭
# bar +3.297e-01  ; 🖋 n1.n10 ➜ Macro❬User#2❭

# %% [markdown]
# The relative frequencies of the macros may be tweaked

# %%
bunch = byron.f.bunch([macro_foo, macro_bar, macro_baz], size=20, weights=[10, 2, 1])
byron.f.as_text(bunch)
# Out:
# ; 🖋 n1 ➜ Frame❬MacroArray#1❭
# foo #5ac2  ; 🖋 n1.n2 ➜ Macro❬User#1❭
# bar +9.414e-01  ; 🖋 n1.n3 ➜ Macro❬User#2❭
# foo #e4a3  ; 🖋 n1.n4 ➜ Macro❬User#1❭
# foo #c744  ; 🖋 n1.n5 ➜ Macro❬User#1❭
# baz 0x3702abf5  ; 🖋 n1.n6 ➜ Macro❬User#3❭
# foo #5ed6  ; 🖋 n1.n7 ➜ Macro❬User#1❭
# bar -6.089e-02  ; 🖋 n1.n8 ➜ Macro❬User#2❭
# foo #3081  ; 🖋 n1.n9 ➜ Macro❬User#1❭
# foo #2142  ; 🖋 n1.n10 ➜ Macro❬User#1❭
# foo #79c7  ; 🖋 n1.n11 ➜ Macro❬User#1❭
# baz 0x3a6db4dc  ; 🖋 n1.n12 ➜ Macro❬User#3❭
# foo #6331  ; 🖋 n1.n13 ➜ Macro❬User#1❭
# bar -4.233e-01  ; 🖋 n1.n14 ➜ Macro❬User#2❭
# foo #aeb8  ; 🖋 n1.n15 ➜ Macro❬User#1❭
# foo #23c6  ; 🖋 n1.n16 ➜ Macro❬User#1❭
# foo #332d  ; 🖋 n1.n17 ➜ Macro❬User#1❭
# foo #01e2  ; 🖋 n1.n18 ➜ Macro❬User#1❭
# bar +5.738e-01  ; 🖋 n1.n19 ➜ Macro❬User#2❭
# foo #aa33  ; 🖋 n1.n20 ➜ Macro❬User#1❭
# foo #b485  ; 🖋 n1.n21 ➜ Macro❬User#1❭

# %% [markdown]
# ## Frames

# %%
all_foo = byron.f.bunch([macro_foo], size=3)
all_bar = byron.f.bunch([macro_bar], size=3)
mix = byron.f.bunch([macro_foo, macro_bar, macro_baz], size=(2, 5 + 1))

# %% [markdown]
# ### Sequences
#
# Create all frames in the sequence

# %%
seq = byron.f.sequence(['begin', all_foo, 'break', all_bar, 'end'])
byron.f.as_text(seq)
# Out:
# ; 🖋 n1 ➜ Frame❬FrameSequence#1❭
# begin  ; 🖋 n1.n2 ➜ Macro❬Text#1❭
# ; 🖋 n1.n3 ➜ Frame❬MacroArray#2❭
# foo #20cc  ; 🖋 n1.n3.n4 ➜ Macro❬User#1❭
# foo #734c  ; 🖋 n1.n3.n5 ➜ Macro❬User#1❭
# foo #5eec  ; 🖋 n1.n3.n6 ➜ Macro❬User#1❭
# break  ; 🖋 n1.n7 ➜ Macro❬Text#2❭
# ; 🖋 n1.n8 ➜ Frame❬MacroArray#3❭
# bar +8.535e-01  ; 🖋 n1.n8.n9 ➜ Macro❬User#2❭
# bar +2.877e-01  ; 🖋 n1.n8.n10 ➜ Macro❬User#2❭
# bar +6.455e-01  ; 🖋 n1.n8.n11 ➜ Macro❬User#2❭
# end  ; 🖋 n1.n12 ➜ Macro❬Text#3❭

# %% [markdown]
# Given the top frame, it is possible to visualize the forest with the syntactic structure (*as_forest*). **Note**: The text is the result of a [depth-first search](https://en.wikipedia.org/wiki/Depth-first_search) of the syntactic structure.
#
# It is also possible to visualize a frame as a, perhaps more intuitive, linear-genetic-programming genome (*as_lgp*)

# %%
byron.f.as_forest(seq)
byron.f.as_lgp(seq)

# %% [markdown]
# ### Alternatives
#
# Randomly chose a frame from the different alternatives

# %%
alt = byron.f.alternative([macro_foo, macro_bar, all_foo, all_bar, 'dummy'])

for n in range(5):
    byron.f.as_text(alt, seed=n)
# Out:
# ; 🖋 n1 ➜ Frame❬FrameAlternative#1❭
# ; 🖋 n1.n2 ➜ Frame❬MacroArray#3❭
# bar +8.255e-01  ; 🖋 n1.n2.n3 ➜ Macro❬User#2❭
# bar +2.133e-01  ; 🖋 n1.n2.n4 ➜ Macro❬User#2❭
# bar +4.590e-01  ; 🖋 n1.n2.n5 ➜ Macro❬User#2❭
#
# ; 🖋 n1 ➜ Frame❬FrameAlternative#1❭
# ; 🖋 n1.n2 ➜ Frame❬MacroArray#2❭
# foo #6c5f  ; 🖋 n1.n2.n3 ➜ Macro❬User#1❭
# foo #d3e4  ; 🖋 n1.n2.n4 ➜ Macro❬User#1❭
# foo #68c1  ; 🖋 n1.n2.n5 ➜ Macro❬User#1❭
#
# ; 🖋 n1 ➜ Frame❬FrameAlternative#1❭
# bar -4.030e-01  ; 🖋 n1.n2 ➜ Macro❬User#2❭
#
# ; 🖋 n1 ➜ Frame❬FrameAlternative#1❭
# foo #3c9f  ; 🖋 n1.n2 ➜ Macro❬User#1❭
#
# ; 🖋 n1 ➜ Frame❬FrameAlternative#1❭
# dummy  ; 🖋 n1.n2 ➜ Macro❬Text#4❭

# %% [markdown]
# ### Nesting Sequences and Alternatives

# %%
all_foo = byron.f.bunch([macro_foo], size=3)
all_bar = byron.f.bunch([macro_bar], size=3)
sequence1 = byron.f.sequence(['; seq1 ----------------------', all_foo, all_bar])
sequence2 = byron.f.sequence(['; seq2 ----------------------', all_bar, all_foo])
alternative = byron.f.alternative([sequence1, sequence2])
final_sequence = byron.f.sequence(
    ['; sseq1 =====================', alternative, '; sseq2 =====================', alternative, alternative]
)

# %%
byron.f.as_text(final_sequence)
byron.f.as_forest(final_sequence)
byron.f.as_lgp(final_sequence)
# Out:
# ; 🖋 n1 ➜ Frame❬FrameSequence#4❭
# ; sseq1 =====================  ; 🖋 n1.n2 ➜ Macro❬Text#7❭
# ; 🖋 n1.n3 ➜ Frame❬FrameAlternative#2❭
# ; 🖋 n1.n3.n4 ➜ Frame❬FrameSequence#3❭
# ; seq2 ----------------------  ; 🖋 n1.n3.n4.n5 ➜ Macro❬Text#6❭
# ; 🖋 n1.n3.n4.n6 ➜ Frame❬MacroArray#5❭
# bar -9.124e-01  ; 🖋 n1.n3.n4.n6.n7 ➜ Macro❬User#2❭
# bar -6.914e-01  ; 🖋 n1.n3.n4.n6.n8 ➜ Macro❬User#2❭
# bar +3.661e-01  ; 🖋 n1.n3.n4.n6.n9 ➜ Macro❬User#2❭
# ; 🖋 n1.n3.n4.n10 ➜ Frame❬MacroArray#4❭
# foo #bea8  ; 🖋 n1.n3.n4.n10.n11 ➜ Macro❬User#1❭
# foo #f7ae  ; 🖋 n1.n3.n4.n10.n12 ➜ Macro❬User#1❭
# foo #5369  ; 🖋 n1.n3.n4.n10.n13 ➜ Macro❬User#1❭
# ; sseq2 =====================  ; 🖋 n1.n14 ➜ Macro❬Text#8❭
# ; 🖋 n1.n15 ➜ Frame❬FrameAlternative#2❭
# ; 🖋 n1.n15.n16 ➜ Frame❬FrameSequence#2❭
# ; seq1 ----------------------  ; 🖋 n1.n15.n16.n17 ➜ Macro❬Text#5❭
# ; 🖋 n1.n15.n16.n18 ➜ Frame❬MacroArray#4❭
# foo #5ed6  ; 🖋 n1.n15.n16.n18.n19 ➜ Macro❬User#1❭
# foo #7834  ; 🖋 n1.n15.n16.n18.n20 ➜ Macro❬User#1❭
# foo #3081  ; 🖋 n1.n15.n16.n18.n21 ➜ Macro❬User#1❭
# ; 🖋 n1.n15.n16.n22 ➜ Frame❬MacroArray#5❭
# bar -7.402e-01  ; 🖋 n1.n15.n16.n22.n23 ➜ Macro❬User#2❭
# bar -4.859e-02  ; 🖋 n1.n15.n16.n22.n24 ➜ Macro❬User#2❭
# bar -5.462e-01  ; 🖋 n1.n15.n16.n22.n25 ➜ Macro❬User#2❭
# ; 🖋 n1.n26 ➜ Frame❬FrameAlternative#2❭
# ; 🖋 n1.n26.n27 ➜ Frame❬FrameSequence#3❭
# ; seq2 ----------------------  ; 🖋 n1.n26.n27.n28 ➜ Macro❬Text#6❭
# ; 🖋 n1.n26.n27.n29 ➜ Frame❬MacroArray#5❭
# bar +3.396e-01  ; 🖋 n1.n26.n27.n29.n30 ➜ Macro❬User#2❭
# bar -1.257e-01  ; 🖋 n1.n26.n27.n29.n31 ➜ Macro❬User#2❭
# bar +6.654e-01  ; 🖋 n1.n26.n27.n29.n32 ➜ Macro❬User#2❭
# ; 🖋 n1.n26.n27.n33 ➜ Frame❬MacroArray#4❭
# foo #b344  ; 🖋 n1.n26.n27.n33.n34 ➜ Macro❬User#1❭
# foo #4ff7  ; 🖋 n1.n26.n27.n33.n35 ➜ Macro❬User#1❭
# foo #d50e  ; 🖋 n1.n26.n27.n33.n36 ➜ Macro❬User#1❭

# %% [markdown]
# ## Frame Names and String Magic
#
# It is possible to specify a (unique) user name for Frames. The name can then be used to specify the frame.

# %%
all_foo = byron.f.bunch([macro_foo], size=3, name='Foo')
all_bar = byron.f.bunch([macro_bar], size=3, name='Bar')

# %%
all_foo == all_bar, all_foo == 'Foo', all_foo == 'Bar'
# Out:
# (False, True, False)

# %%
set([all_foo, 'Foo', 'Bar', all_bar])
# Out:
# {'Bar', Frame❰Foo❱}
