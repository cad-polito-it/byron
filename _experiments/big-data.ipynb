# %% [markdown]
# This notebook is part of [**Byron v0.8**](https://pypi.org/project/byron/)
# Copyright 2023-25 Giovanni Squillero and Alberto Tonda
# SPDX-License-Identifier: [Apache-2.0](https://opensource.org/license/apache-2-0/)

# %%
import byron
# Out:
# /var/folders/31/dkl97hks2c14b663vl55pt440000gn/T/ipykernel_19814/1429530752.py:1: ByronPerformanceWarning:
#   Paranoia checks are enabled in this notebook: performances can be significantly impaired
#   [see https://cad-polito-it.github.io/byron/paranoia for details]
#   import byron

# %%
single_data = byron.f.integer_parameter(0, 2 ** 8)
data = byron.f.sequence([single_data, ','])
blob = byron.f.bunch([data], size=32)
byron.f.as_forest(blob)

# %%
byron.f.estimate_size(byron.f.bunch([data], size=32 * 1024))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 byron.f.estimate_size(byron.f.bunch([data], size=32 * 1024))
#
# File ~/Repos/byron/src/byron/framework/show_element.py:135, in estimate_size(element, seed)
#     133 else:
#     134     individual = _generate_random_individual(element, seed=seed)
# --> 135 size = individual.size
#     136 bp = ['', 'Ki', 'Mi', 'Gi', 'Ti', 'Pi', 'Ei', 'Zi']
#     137 i = 0
#
# File ~/Repos/byron/src/byron/classes/individual.py:160, in Individual.size(self)
#     158 s = sys.getsizeof(self._fitness)
#     159 s += sum(sys.getsizeof(n) for n in self._genome.nodes) + sum(sys.getsizeof(e) for e in self._genome.edges)
# --> 160 s += sum(self._genome.nodes[n]['_selement'].size for n in self._genome)
#     161 return s
#
# File ~/Repos/byron/src/byron/classes/individual.py:160, in <genexpr>(.0)
#     158 s = sys.getsizeof(self._fitness)
#     159 s += sum(sys.getsizeof(n) for n in self._genome.nodes) + sum(sys.getsizeof(e) for e in self._genome.edges)
# --> 160 s += sum(self._genome.nodes[n]['_selement'].size for n in self._genome)
#     161 return s
#
# AttributeError: 'MacroZero' object has no attribute 'size'

# %%
data = byron.f.array_parameter(range(2 ** 8), 32 * 1024, sep=', ')
macro = byron.f.macro("{mem}", mem=data)
byron.f.as_forest(macro)

# %%
byron.f.estimate_size(macro)

# %%
byron.f.as_text(macro)
